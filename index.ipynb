# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head(1000)
# Out:
# 197625
#       C/A  UNIT       SCP     STATION LINENAME DIVISION        DATE      TIME  \
# 0    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/25/2018  16:00:00
# 5    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/25/2018  20:00:00
# 6    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/26/2018  00:00:00
# 7    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/26/2018  04:00:00
# 8    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/26/2018  08:00:00
# 9    A002  R051  02-00-00       59 ST  NQR456W      BMT  08/26/2018  12:00:00
# 10   A002  R051  02-00-00       59 ST  NQR456W      BMT  08/26/2018  16:00:00
# ...

# %%
station_vco.head()

# %%
df.head()

# %%
df.groupby('STATION')
df.STATION.value_counts()
station_vco=df.STATION.value_counts()
stations_descending_keys = list(station_vco.keys())
stations_value_count_list = list(station_vco)
stations_value_count_list[:5]
# Out:
# [4080, 4019, 2768, 2605, 2401]

# %%
df.loc[:,['STATION']][0:1]

# %%
df['STATION'][1]
# Out:
# '59 ST'

# %%
station_vco
# Out:
# FULTON ST          4080
# 34 ST-PENN STA     4019
# GRD CNTRL-42 ST    2768
# 23 ST              2605
# CANAL ST           2401
# 34 ST-HERALD SQ    2311
# CHAMBERS ST        2268
# 59 ST              2229
# 42 ST-PORT AUTH    2181
# TIMES SQ-42 ST     2124
# WALL ST            2037
# ATL AV-BARCLAY     2011
# 86 ST              1968
# 125 ST             1852
# 14 ST              1803
# PATH NEW WTC       1800
# 59 ST COLUMBUS     1734
# CORTLANDT ST       1682
# 47-50 STS ROCK     1616
# 14 ST-UNION SQ     1604
# 161/YANKEE STAD    1587
# CHURCH AV          1565
# 96 ST              1553
# JAY ST-METROTEC    1548
# METS-WILLETS PT    1548
# 50 ST              1546
# LEXINGTON AV/53    1399
# 34 ST-HUDSON YD    1260
# BOWLING GREEN      1218
# FLUSHING-MAIN      1198
#                    ...
# BAYCHESTER AV       126
# VAN SICLEN AVE      126
# MORRIS PARK         126
# LIBERTY AV          126
# YORK ST             126
# BOWERY              126
# ALABAMA AV          126
# ...

# %%
df['Num Lines'] = df['STATION'].apply(lambda x: station_vco[x])

# %%
# for x in range(0,len(df)):
#     for y in range(0, len(stations_descending_keys)):
#         #if df.loc[:,['STATION']][x:(x+1)]==stations_descending_keys[y]:
#         if df['STATION'][x]==stations_descending_keys[y]:
#             df['Num Lines'].iloc[x]=stations_value_count_list[y]


#df['Num Lines'] = my_function(df.param1, df.param1.shift(1), df.param2.shift(1))

# %%
zero_list = [0]*len(df)
df['Num Lines']=zero_list

# %%
df.loc[df['STATION']=='SUTTER AV'].head()
# Out:
#         C/A  UNIT       SCP    STATION LINENAME DIVISION        DATE  \
# 34355  H037  R349  00-00-00  SUTTER AV        L      BMT  08/25/2018
# 34356  H037  R349  00-00-00  SUTTER AV        L      BMT  08/25/2018
# 34357  H037  R349  00-00-00  SUTTER AV        L      BMT  08/25/2018
# 34358  H037  R349  00-00-00  SUTTER AV        L      BMT  08/25/2018
# 34359  H037  R349  00-00-00  SUTTER AV        L      BMT  08/25/2018
#
#            TIME     DESC  ENTRIES  \
# 34355  01:00:00  REGULAR  1112236
# 34356  05:00:00  REGULAR  1112296
# 34357  09:00:00  REGULAR  1112575
# 34358  13:00:00  REGULAR  1112920
# 34359  17:00:00  REGULAR  1113265
#
#        EXITS                                                                 \
# 34355                                            1217828
# 34356                                            1217967
# 34357                                            1218170
# 34358                                            1218492
# ...

# %%
#df.iloc[1]

# %%
for x in df
    if df.iloc[x]['STATION']==

# %% [markdown]
# ## Rename all the columns to lower case

# %%
column_list = list(df.columns)

# %%
column_list_lower = [x.lower().strip() for x in column_list]
column_list_lower

# %%
df.columns = [column_list_lower]
df.head()

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
df2 = df._index('linename')
# df.index[0]
# df.head()

# %%
df2.head()
df2.index[0]

# %% [markdown]
# ## Painstakingly change the index back

# %%
df2.reset_index()

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order

# %%
#df.columns
#df.reset_index()
#df.groupby(['station'])
#did this above

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(col_name):
    cleaned = col_name.lower().title()
    return cleaned

# %%
clean('ALKSJDF ALSDJF')
# Out:
# 'Alksjdf Alsdjf'

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['C/A', 'Unit', 'Scp', 'Station', 'Linename', 'Division', 'Date', 'Time',
#        'Desc', 'Entries',
#        'Exits                                                               ',
#        'Num Lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
df['Date'][:1].iloc[0]
# Out:
# '08/25/2018'

# %%
int(list(df['Date'][:1])[0].replace("/", ""))
# Out:
# 8252018

# %%
def convert_date(date)
    removed_slash = int(list(x[0].replace("/", ""))
    dt_list = [0,0,0]
    
    for x in range(0,2):
        dt_list[2-x] = (removed_slash[-4]+

# %%
#df['Num Lines'] = df['STATION'].apply(lambda x: station_vco[x])
import datetime
from datetime import date
df['DT'] = df['Date'].apply(lambda x: convert_date(x))

# %%
from datetime import date
import calendar
my_date = date.today()
calendar.day_name[my_date.weekday()]
# Out:
# 'Friday'

# %%
my_date
# Out:
# datetime.date(2019, 4, 26)

# %%
import datetime

d = datetime.date(2019, 4, 13)
type(d)
# Out:
# datetime.date

# %%
df[['Entries','Date']]
# Out:
#         Entries        Date
# 0       6736067  08/25/2018
# 1       6736087  08/25/2018
# 2       6736105  08/25/2018
# 3       6736180  08/25/2018
# 4       6736349  08/25/2018
# 5       6736562  08/25/2018
# 6       6736683  08/26/2018
# 7       6736696  08/26/2018
# 8       6736705  08/26/2018
# 9       6736746  08/26/2018
# 10      6736873  08/26/2018
# 11      6737067  08/26/2018
# 12      6737136  08/27/2018
# 13      6737146  08/27/2018
# 14      6737169  08/27/2018
# 15      6737301  08/27/2018
# 16      6737553  08/27/2018
# 17      6738257  08/27/2018
# 18      6738430  08/28/2018
# 19      6738442  08/28/2018
# 20      6738474  08/28/2018
# 21      6738621  08/28/2018
# 22      6738886  08/28/2018
# 23      6739630  08/28/2018
# 24      6739804  08/29/2018
# 25      6739812  08/29/2018
# 26      6739847  08/29/2018
# 27      6739986  08/29/2018
# 28      6740257  08/29/2018
# 29      6740888  08/29/2018
# ...         ...         ...
# 197595     5554  08/27/2018
# ...

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes

# %%
#Your code here

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
